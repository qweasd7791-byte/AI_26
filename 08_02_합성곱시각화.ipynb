# %% [markdown]
# <a href="https://colab.research.google.com/github/qweasd7791-byte/AI_26/blob/main/08_02_%ED%95%A9%EC%84%B1%EA%B3%B1%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 요약: 서리
# 과대적합 막기: 드롭아웃

# %%
# 합성곱 시각망의 시각화
# 합성곱층의 가중치와 특성맵을 시각화하여
